# %%
from datetime import datetime, timedelta
import json
import requests
import time

BASE_URL = "https://api.weather.gov"
RATE_LIMIT_SECONDS = 1   # prevent the API from getting mad for requesting too much data at once

def print_readable_json(json_string):
    readable_json = json.dumps(json_string, indent=4, sort_keys=True)
    print(readable_json)

# %% [markdown]
# # Get all stations in GA
#
# Print the first 10

# %%
response = requests.get(f"{BASE_URL}/stations?state=GA")
stations = response.json()["features"][0:10]
print_readable_json(stations)
# Out:
# [
#     {
#         "geometry": {
#             "coordinates": [
#                 -84.39281,
#                 33.77232
#             ],
#             "type": "Point"
#         },
#         "id": "https://api.weather.gov/stations/0349W",
#         "properties": {
#             "@id": "https://api.weather.gov/stations/0349W",
#             "@type": "wx:ObservationStation",
#             "county": "https://api.weather.gov/zones/county/GAC121",
#             "elevation": {
#                 "unitCode": "wmoUnit:m",
#                 "value": 291.9984
#             },
#             "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ033",
#             "forecast": "https://api.weather.gov/zones/forecast/GAZ033",
#             "name": "Georgia Tech Bobby Dodd Stadium",
#             "stationIdentifier": "0349W",
#             "timeZone": "America/New_York"
#         },
#         "type": "Feature"
#     },
#     {
#         "geometry": {
#             "coordinates": [
#                 -84.40367,
#                 33.77494
#             ],
#             "type": "Point"
#         },
#         "id": "https://api.weather.gov/stations/0353W",
#         "properties": {
#             "@id": "https://api.weather.gov/stations/0353W",
#             "@type": "wx:ObservationStation",
#             "county": "https://api.weather.gov/zones/county/GAC121",
#             "elevation": {
#                 "unitCode": "wmoUnit:m",
#                 "value": 305.1048
#             },
#             "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ033",
#             "forecast": "https://api.weather.gov/zones/forecast/GAZ033",
#             "name": "Georgia Tech Campus Recreation Center",
#             "stationIdentifier": "0353W",
#             "timeZone": "America/New_York"
#         },
#         "type": "Feature"
#     },
#     {
#         "geometry": {
#             "coordinates": [
#                 -83.4099899,
#                 33.8473
#             ],
#             "type": "Point"
#         },
#         "id": "https://api.weather.gov/stations/0414W",
#         "properties": {
#             "@id": "https://api.weather.gov/stations/0414W",
#             "@type": "wx:ObservationStation",
#             "county": "https://api.weather.gov/zones/county/GAC219",
#             "elevation": {
#                 "unitCode": "wmoUnit:m",
#                 "value": 227.076
#             },
#             "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ037",
#             "forecast": "https://api.weather.gov/zones/forecast/GAZ037",
#             "name": "Colham Ferry Elementary School",
#             "stationIdentifier": "0414W",
#             "timeZone": "America/New_York"
#         },
#         "type": "Feature"
#     },
#     {
#         "geometry": {
#             "coordinates": [
#                 -83.38258,
#                 33.9051199
#             ],
#             "type": "Point"
#         },
#         "id": "https://api.weather.gov/stations/0472W",
#         "properties": {
#             "@id": "https://api.weather.gov/stations/0472W",
#             "@type": "wx:ObservationStation",
#             "county": "https://api.weather.gov/zones/county/GAC059",
#             "elevation": {
#                 "unitCode": "wmoUnit:m",
#                 "value": 213.0552
#             },
#             "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ036",
#             "forecast": "https://api.weather.gov/zones/forecast/GAZ036",
#             "name": "State Botanical Garden of Georgia",
#             "stationIdentifier": "0472W",
#             "timeZone": "America/New_York"
#         },
#         "type": "Feature"
#     },
#     {
#         "geometry": {
#             "coordinates": [
#                 -83.37544,
#                 33.94865
#             ],
#             "type": "Point"
#         },
#         "id": "https://api.weather.gov/stations/0475W",
#         "properties": {
#             "@id": "https://api.weather.gov/stations/0475W",
#             "@type": "wx:ObservationStation",
#             "county": "https://api.weather.gov/zones/county/GAC059",
#             "elevation": {
#                 "unitCode": "wmoUnit:m",
#                 "value": 213.9696
#             },
#             "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ036",
#             "forecast": "https://api.weather.gov/zones/forecast/GAZ036",
#             "name": "UGA Climatology Research Lab",
#             "stationIdentifier": "0475W",
#             "timeZone": "America/New_York"
#         },
#         "type": "Feature"
#     },
#     {
#         "geometry": {
#             "coordinates": [
#                 -83.708,
#                 31.13787
#             ],
#             "type": "Point"
#         },
#         "id": "https://api.weather.gov/stations/0486W",
#         "properties": {
#             "@id": "https://api.weather.gov/stations/0486W",
#             "@type": "wx:ObservationStation",
#             "county": "https://api.weather.gov/zones/county/GAC071",
#             "elevation": {
#                 "unitCode": "wmoUnit:m",
#                 "value": 86.868
#             },
#             "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ146",
#             "forecast": "https://api.weather.gov/zones/forecast/GAZ146",
#             "name": "SunBelt Ag Expo",
#             "stationIdentifier": "0486W",
#             "timeZone": "America/New_York"
#         },
#         "type": "Feature"
#     },
#     {
#         "geometry": {
#             "coordinates": [
#                 -83.89849,
#                 33.96774
#             ],
#             "type": "Point"
#         },
#         "id": "https://api.weather.gov/stations/0500W",
#         "properties": {
#             "@id": "https://api.weather.gov/stations/0500W",
#             "@type": "wx:ObservationStation",
#             "county": "https://api.weather.gov/zones/county/GAC135",
#             "elevation": {
#                 "unitCode": "wmoUnit:m",
#                 "value": 334.0608
#             },
#             "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ034",
#             "forecast": "https://api.weather.gov/zones/forecast/GAZ034",
#             "name": "Alcova Elementary School",
#             "stationIdentifier": "0500W",
#             "timeZone": "America/New_York"
#         },
#         "type": "Feature"
#     },
#     {
#         "geometry": {
#             "coordinates": [
#                 -83.99152,
#                 34.12945
#             ],
#             "type": "Point"
#         },
#         "id": "https://api.weather.gov/stations/0535W",
#         "properties": {
#             "@id": "https://api.weather.gov/stations/0535W",
#             "@type": "wx:ObservationStation",
#             "county": "https://api.weather.gov/zones/county/GAC135",
#             "elevation": {
#                 "unitCode": "wmoUnit:m",
#                 "value": 360.8832
#             },
#             "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ034",
#             "forecast": "https://api.weather.gov/zones/forecast/GAZ034",
#             "name": "Buford Academy",
#             "stationIdentifier": "0535W",
#             "timeZone": "America/New_York"
#         },
#         "type": "Feature"
#     },
#     {
#         "geometry": {
#             "coordinates": [
#                 -84.32418,
#                 33.80004
#             ],
#             "type": "Point"
#         },
#         "id": "https://api.weather.gov/stations/0536W",
#         "properties": {
#             "@id": "https://api.weather.gov/stations/0536W",
#             "@type": "wx:ObservationStation",
#             "county": "https://api.weather.gov/zones/county/GAC089",
#             "elevation": {
#                 "unitCode": "wmoUnit:m",
#                 "value": 305.1048
#             },
#             "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ045",
#             "forecast": "https://api.weather.gov/zones/forecast/GAZ045",
#             "name": "Emory Atlanta Campus",
#             "stationIdentifier": "0536W",
#             "timeZone": "America/New_York"
#         },
#         "type": "Feature"
#     },
#     {
#         "geometry": {
#             "coordinates": [
#                 -83.87124,
#                 33.6203
#             ],
#             "type": "Point"
#         },
#         "id": "https://api.weather.gov/stations/0538W",
#         "properties": {
#             "@id": "https://api.weather.gov/stations/0538W",
#             "@type": "wx:ObservationStation",
#             "county": "https://api.weather.gov/zones/county/GAC217",
#             "elevation": {
#                 "unitCode": "wmoUnit:m",
#                 "value": 235.9152
#             },
#             "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ048",
#             "forecast": "https://api.weather.gov/zones/forecast/GAZ048",
#             "name": "Oxford College of Emory University",
#             "stationIdentifier": "0538W",
#             "timeZone": "America/New_York"
#         },
#         "type": "Feature"
#     }
# ]

# %% [markdown]
# # Show metadata about CRC observation station

# %%
response = requests.get(f"{BASE_URL}/stations/0353W")
print_readable_json(response.json()["properties"])
# Out:
# {
#     "@id": "https://api.weather.gov/stations/0353W",
#     "@type": "wx:ObservationStation",
#     "county": "https://api.weather.gov/zones/county/GAC121",
#     "elevation": {
#         "unitCode": "wmoUnit:m",
#         "value": 305.1048
#     },
#     "fireWeatherZone": "https://api.weather.gov/zones/fire/GAZ033",
#     "forecast": "https://api.weather.gov/zones/forecast/GAZ033",
#     "name": "Georgia Tech Campus Recreation Center",
#     "stationIdentifier": "0353W",
#     "timeZone": "America/New_York"
# }

# %% [markdown]
# # Show latest observations at CRC observation station

# %%
response = requests.get(f"{BASE_URL}/stations/0353W/observations/latest")
print_readable_json(response.json()["properties"])
# Out:
# {
#     "@id": "https://api.weather.gov/stations/0353W/observations/2024-01-17T22:20:00+00:00",
#     "@type": "wx:ObservationStation",
#     "barometricPressure": {
#         "qualityControl": "V",
#         "unitCode": "wmoUnit:Pa",
#         "value": 102336.62
#     },
#     "cloudLayers": [],
#     "dewpoint": {
#         "qualityControl": "V",
#         "unitCode": "wmoUnit:degC",
#         "value": -13.89
#     },
#     "elevation": {
#         "unitCode": "wmoUnit:m",
#         "value": 305.1
#     },
#     "heatIndex": {
#         "qualityControl": "V",
#         "unitCode": "wmoUnit:degC",
#         "value": null
#     },
#     "icon": null,
#     "maxTemperatureLast24Hours": {
#         "unitCode": "wmoUnit:degC",
#         "value": null
#     },
#     "minTemperatureLast24Hours": {
#         "unitCode": "wmoUnit:degC",
#         "value": null
#     },
#     "precipitationLast3Hours": {
#         "qualityControl": "Z",
#         "unitCode": "wmoUnit:mm",
#         "value": null
#     },
#     "presentWeather": [],
#     "rawMessage": "",
#     "relativeHumidity": {
#         "qualityControl": "V",
#         "unitCode": "wmoUnit:percent",
#         "value": 30.117529123576
#     },
#     "seaLevelPressure": {
#         "qualityControl": "Z",
#         "unitCode": "wmoUnit:Pa",
#         "value": null
#     },
#     "station": "https://api.weather.gov/stations/0353W",
#     "temperature": {
#         "qualityControl": "V",
#         "unitCode": "wmoUnit:degC",
#         "value": 1.83
#     },
#     "textDescription": "",
#     "timestamp": "2024-01-17T22:20:00+00:00",
#     "visibility": {
#         "qualityControl": "Z",
#         "unitCode": "wmoUnit:m",
#         "value": null
#     },
#     "windChill": {
#         "qualityControl": "V",
#         "unitCode": "wmoUnit:degC",
#         "value": null
#     },
#     "windDirection": {
#         "qualityControl": "Z",
#         "unitCode": "wmoUnit:degree_(angle)",
#         "value": null
#     },
#     "windGust": {
#         "qualityControl": "Z",
#         "unitCode": "wmoUnit:km_h-1",
#         "value": null
#     },
#     "windSpeed": {
#         "qualityControl": "V",
#         "unitCode": "wmoUnit:km_h-1",
#         "value": 0
#     }
# }

# %% [markdown]
# # Get barometric pressure at observation station for specific days
#
# Observations appear to be hourly.  Timestamp in the route parameters is an ISO-8601 string, with no fractional seconds

# %%
response = requests.get(f"{BASE_URL}/stations/0353W/observations/2024-01-16T13:00:00Z")
print_readable_json(response.json())
# Out:
# {
#     "@context": [
#         "https://geojson.org/geojson-ld/geojson-context.jsonld",
#         {
#             "@version": "1.1",
#             "@vocab": "https://api.weather.gov/ontology#",
#             "bearing": {
#                 "@type": "s:QuantitativeValue"
#             },
#             "city": "s:addressLocality",
#             "county": {
#                 "@type": "@id"
#             },
#             "distance": {
#                 "@id": "s:Distance",
#                 "@type": "s:QuantitativeValue"
#             },
#             "forecastGridData": {
#                 "@type": "@id"
#             },
#             "forecastOffice": {
#                 "@type": "@id"
#             },
#             "geo": "http://www.opengis.net/ont/geosparql#",
#             "geometry": {
#                 "@id": "s:GeoCoordinates",
#                 "@type": "geo:wktLiteral"
#             },
#             "publicZone": {
#                 "@type": "@id"
#             },
#             "s": "https://schema.org/",
#             "state": "s:addressRegion",
#             "unit": "http://codes.wmo.int/common/unit/",
#             "unitCode": {
#                 "@id": "s:unitCode",
#                 "@type": "@id"
#             },
#             "value": {
#                 "@id": "s:value"
#             },
#             "wx": "https://api.weather.gov/ontology#"
#         }
#     ],
#     "geometry": {
#         "coordinates": [
#             -84.4,
#             33.77
#         ],
#         "type": "Point"
#     },
#     "id": "https://api.weather.gov/stations/0353W/observations/2024-01-16T13:00:00+00:00",
#     "properties": {
#         "@id": "https://api.weather.gov/stations/0353W/observations/2024-01-16T13:00:00+00:00",
#         "@type": "wx:ObservationStation",
#         "barometricPressure": {
#             "qualityControl": "Z",
#             "unitCode": "wmoUnit:Pa",
#             "value": null
#         },
#         "cloudLayers": [],
#         "dewpoint": {
#             "qualityControl": "V",
#             "unitCode": "wmoUnit:degC",
#             "value": -0.03
#         },
#         "elevation": {
#             "unitCode": "wmoUnit:m",
#             "value": 305.1
#         },
#         "heatIndex": {
#             "qualityControl": "V",
#             "unitCode": "wmoUnit:degC",
#             "value": null
#         },
#         "icon": null,
#         "maxTemperatureLast24Hours": {
#             "unitCode": "wmoUnit:degC",
#             "value": null
#         },
#         "minTemperatureLast24Hours": {
#             "unitCode": "wmoUnit:degC",
#             "value": null
#         },
#         "precipitationLast3Hours": {
#             "qualityControl": "Z",
#             "unitCode": "wmoUnit:mm",
#             "value": null
#         },
#         "presentWeather": [],
#         "rawMessage": "",
#         "relativeHumidity": {
#             "qualityControl": "V",
#             "unitCode": "wmoUnit:percent",
#             "value": 90.981522105916
#         },
#         "seaLevelPressure": {
#             "qualityControl": "Z",
#             "unitCode": "wmoUnit:Pa",
#             "value": null
#         },
#         "station": "https://api.weather.gov/stations/0353W",
#         "temperature": {
#             "qualityControl": "V",
#             "unitCode": "wmoUnit:degC",
#             "value": 1.28
#         },
#         "textDescription": "",
#         "timestamp": "2024-01-16T13:00:00+00:00",
#         "visibility": {
#             "qualityControl": "Z",
#             "unitCode": "wmoUnit:m",
#             "value": null
#         },
#         "windChill": {
#             "qualityControl": "V",
#             "unitCode": "wmoUnit:degC",
#             "value": null
#         },
#         "windDirection": {
#             "qualityControl": "V",
#             "unitCode": "wmoUnit:degree_(angle)",
#             "value": 29
#         },
#         "windGust": {
#             "qualityControl": "Z",
#             "unitCode": "wmoUnit:km_h-1",
#             "value": null
#         },
#         "windSpeed": {
#             "qualityControl": "V",
#             "unitCode": "wmoUnit:km_h-1",
#             "value": 1.62
#         }
#     },
#     "type": "Feature"
# }

# %%
def format_timestamp(raw_datetime):
    # NOAA API only records observations at hourly intervals with a Zulu UTC offset
    return raw_datetime.strftime("%Y-%m-%dT%H:00:00Z")

def request_barometric_pressure(station, timestamp):
    response = requests.get(f"{BASE_URL}/stations/{station}/observations/{timestamp}")
    time.sleep(RATE_LIMIT_SECONDS)
    if response.status_code == 404:
        print(f"Data not found for date: {timestamp}")
        return ()
    else:
        pressure_data = response.json()["properties"]["barometricPressure"]
        return (pressure_data["qualityControl"], pressure_data["unitCode"], pressure_data["value"])

STATION_CODE = "0353W"  # CRC station
HOUR_CONSTANT = 13      # getting pressure at a fixed hour every day (8 or 9AM Eastern depending on whether DST is on)
now = datetime.now()
start_datetime = now.replace(hour=HOUR_CONSTANT)
timestamps = [format_timestamp(start_datetime - timedelta(days=i)) for i in range(10)]
pressures = [request_barometric_pressure(STATION_CODE, time) for time in timestamps]
print(pressures)
# Out:
# Data not found for date: 2024-01-10T13:00:00Z
# Data not found for date: 2024-01-09T13:00:00Z
# Data not found for date: 2024-01-08T13:00:00Z
# [('V', 'wmoUnit:Pa', 102404.34), ('Z', 'wmoUnit:Pa', None), ('Z', 'wmoUnit:Pa', None), ('Z', 'wmoUnit:Pa', None), ('Z', 'wmoUnit:Pa', None), ('Z', 'wmoUnit:Pa', None), ('Z', 'wmoUnit:Pa', None), (), (), ()]

# %% [markdown]
# Looks like data is only kept for around a week.  Also, the "quality control" code `Z` might have some impact as to whether there is data or not.
